# %% [markdown]
# <a href="https://colab.research.google.com/github/WebDevJonny/pythonjourney/blob/main/logbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
wallet = 10
tea_price = 3

if wallet < tea_price:
  print ("you cannot afford this!")
else:
  print ("transaction complete. here is your tea")
# Out:
# transaction complete. here is your tea

# %%
order = input("Welcome! Would you like Coffee or Tea?").capitalize()

if order == "Coffee":
  print("That will be $5. Preparing your brew!")
elif order == "Tea":
    print ("That will be $3. Steeping your tea!")
else:
    print("Sorry, we don't have that on the menu.")
# Out:
# Welcome! Would you like Coffee or Tea?tea
# That will be $3. Steeping your tea!
